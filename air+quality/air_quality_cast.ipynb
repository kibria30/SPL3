# %%
import pandas as pd

df = pd.read_excel('AirQualityUCI.xlsx')
df.head()
# Out:
#         Date      Time  CO(GT)  PT08.S1(CO)  NMHC(GT)   C6H6(GT)  \
# 0 2004-03-10  18:00:00     2.6      1360.00       150  11.881723
# 1 2004-03-10  19:00:00     2.0      1292.25       112   9.397165
# 2 2004-03-10  20:00:00     2.2      1402.00        88   8.997817
# 3 2004-03-10  21:00:00     2.2      1375.50        80   9.228796
# 4 2004-03-10  22:00:00     1.6      1272.25        51   6.518224
#
#    PT08.S2(NMHC)  NOx(GT)  PT08.S3(NOx)  NO2(GT)  PT08.S4(NO2)  PT08.S5(O3)  \
# 0        1045.50    166.0       1056.25    113.0       1692.00      1267.50
# 1         954.75    103.0       1173.75     92.0       1558.75       972.25
# 2         939.25    131.0       1140.00    114.0       1554.50      1074.00
# 3         948.25    172.0       1092.00    122.0       1583.75      1203.25
# 4         835.50    131.0       1205.00    116.0       1490.00      1110.00
#
#        T         RH        AH
# 0  13.60  48.875001  0.757754
# 1  13.30  47.700000  0.725487
# 2  11.90  53.975000  0.750239
# 3  11.00  60.000000  0.786713
# 4  11.15  59.575001  0.788794

# %%
df_cleaned = df.iloc[6:, :].reset_index(drop=True)
df_cleaned.head()
# Out:
#         Date      Time  CO(GT)  PT08.S1(CO)  NMHC(GT)  C6H6(GT)  \
# 0 2004-03-11  00:00:00     1.2      1185.00        31  3.624399
# 1 2004-03-11  01:00:00     1.0      1136.25        31  3.326677
# 2 2004-03-11  02:00:00     0.9      1094.00        24  2.339416
# 3 2004-03-11  03:00:00     0.6      1009.75        19  1.696658
# 4 2004-03-11  04:00:00  -200.0      1011.00        14  1.293620
#
#    PT08.S2(NMHC)  NOx(GT)  PT08.S3(NOx)  NO2(GT)  PT08.S4(NO2)  PT08.S5(O3)  \
# 0         689.50     62.0       1461.75     77.0       1332.75       732.50
# 1         672.00     62.0       1453.25     76.0       1332.75       729.50
# 2         608.50     45.0       1579.00     60.0       1276.00       619.50
# 3         560.75   -200.0       1705.00   -200.0       1234.75       501.25
# 4         526.75     21.0       1817.50     34.0       1196.75       445.25
#
#         T         RH        AH
# 0  11.325  56.775000  0.760312
# 1  10.675  60.000000  0.770238
# 2  10.650  59.674999  0.764819
# 3  10.250  60.200001  0.751657
# 4  10.075  60.474999  0.746495

# %%
df_cleaned.iloc[9349]
# Out:
# Date             2005-04-04 00:00:00
# Time                        13:00:00
# CO(GT)                           2.1
# PT08.S1(CO)                   1002.5
# NMHC(GT)                        -200
# C6H6(GT)                    9.547187
# PT08.S2(NMHC)                  960.5
# NOx(GT)                        234.5
# PT08.S3(NOx)                   701.5
# NO2(GT)                        155.7
# PT08.S4(NO2)                  1041.0
# PT08.S5(O3)                   769.75
# T                             28.325
# RH                             13.55
# AH                          0.513866
# Name: 9349, dtype: object

# %%
df_cleaned.shape
# Out:
# (9351, 15)

# %%
9351/24
# Out:
# 389.625

# %%
389*24
# Out:
# 9336

# %%
import matplotlib.pyplot as plt

ch_1 = ch[:200]
plt.figure(figsize=(12, 6))
plt.plot(ch_1)

# %%
time_x = df[['Date', 'Time', 'NMHC(GT)']].copy()

time_cleaned = time_x[6:]
time_cleaned.head(24*5)
# Out:
#           Date      Time  NMHC(GT)
# 6   2004-03-11  00:00:00        31
# 7   2004-03-11  01:00:00        31
# 8   2004-03-11  02:00:00        24
# 9   2004-03-11  03:00:00        19
# 10  2004-03-11  04:00:00        14
# ..         ...       ...       ...
# 121 2004-03-15  19:00:00       685
# 122 2004-03-15  20:00:00       538
# 123 2004-03-15  21:00:00       319
# 124 2004-03-15  22:00:00       224
# 125 2004-03-15  23:00:00        67
#
# [120 rows x 3 columns]

# %%
plt.figure(figsize=(12, 6))
plt.plot(time_cleaned['NMHC(GT)'][:24*5])
